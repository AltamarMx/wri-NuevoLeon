# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from slugify import slugify  # pip install python-slugify
import seaborn as sns
import matplotlib.patches as mpatches

# %%
f = "../data/002_intermediate/apf_long.parquet"
apf = pd.read_parquet(f)
del apf["ent_mun"]
# del apf["consumo"]
# del apf["area"]
del apf["municipio"]
del apf["especifico"]
apf
# Out:
#                  generico           entidad      area  aa       emensual  \
# 0     Educación y Cultura  CIUDAD DE MEXICO   1527.52  NO    1288.583333
# 1         Oficina Pública  CIUDAD DE MEXICO   6705.41  NO   13218.861111
# 2         Oficina Pública  CIUDAD DE MEXICO   5037.00  SI   10814.527778
# 3     Educación y Cultura  CIUDAD DE MEXICO   4000.00  NO    5136.666667
# 4         Oficina Pública  CIUDAD DE MEXICO   8370.02  SI   14326.666667
# ...                   ...               ...       ...  ..            ...
# 1817  Educación y Cultura            MÉXICO   2355.54  NO      24.222222
# 1818      Infraestructura           HIDALGO   3430.00  NO   61951.861111
# 1819      Oficina Pública          COAHUILA   1072.59  SI     321.805556
# 1820      Oficina Pública        NUEVO LEÓN   2971.00  SI    7706.138889
# 1821  Educación y Cultura  CIUDAD DE MEXICO  40000.00  SI  108548.527778
#
#       emensualm2         bioclima
# 0       0.843579  Templado Húmedo
# 1       1.971373  Templado Húmedo
# 2       2.147018  Templado Húmedo
# 3       1.284167  Templado Húmedo
# 4       1.711665  Templado Húmedo
# ...          ...              ...
# 1817    0.010283         Semifrío
# 1818   18.061767         Templado
# 1819    0.300027    Templado Seco
# 1820    2.593786    Templado Seco
# 1821    2.713713  Templado Húmedo
#
# [1822 rows x 7 columns]

# %%
apf.generico.unique()
# Out:
# array(['Educación y Cultura', 'Oficina Pública', 'Industria', 'Seguridad',
#        'Comunicaciones y Transporte', 'Infraestructura',
#        'Agrícola, Pecuario y Forestal', 'Salud', 'Comercio', 'Recreación',
#        'Habitacional', 'Alojamiento', 'Servicios Funerarios'],
#       dtype=object)

# %%
apf_naa = apf[apf.aa=='NO']
apf_naa
# Out:
#                  generico           entidad     area  aa      emensual  \
# 0     Educación y Cultura  CIUDAD DE MEXICO  1527.52  NO   1288.583333
# 1         Oficina Pública  CIUDAD DE MEXICO  6705.41  NO  13218.861111
# 3     Educación y Cultura  CIUDAD DE MEXICO  4000.00  NO   5136.666667
# 5     Educación y Cultura  CIUDAD DE MEXICO  3427.00  NO   2086.722222
# 6         Oficina Pública  CIUDAD DE MEXICO  7468.00  NO   9900.000000
# ...                   ...               ...      ...  ..           ...
# 1812      Oficina Pública            OAXACA  1168.78  NO    515.861111
# 1814      Infraestructura  CIUDAD DE MEXICO  3066.46  NO    290.250000
# 1815      Oficina Pública            MÉXICO  1255.00  NO   1855.472222
# 1817  Educación y Cultura            MÉXICO  2355.54  NO     24.222222
# 1818      Infraestructura           HIDALGO  3430.00  NO  61951.861111
#
#       emensualm2           bioclima
# 0       0.843579    Templado Húmedo
# 1       1.971373    Templado Húmedo
# 3       1.284167    Templado Húmedo
# 5       0.608906    Templado Húmedo
# 6       1.325656    Templado Húmedo
# ...          ...                ...
# 1812    0.441367  Cálido Semihúmedo
# 1814    0.094653    Templado Húmedo
# 1815    1.478464           Semifrío
# 1817    0.010283           Semifrío
# 1818   18.061767           Templado
#
# [721 rows x 7 columns]

# %%
apf_naa
# Out:
#                  generico           entidad     area  aa      emensual  \
# 0     Educación y Cultura  CIUDAD DE MEXICO  1527.52  NO   1288.583333
# 1         Oficina Pública  CIUDAD DE MEXICO  6705.41  NO  13218.861111
# 3     Educación y Cultura  CIUDAD DE MEXICO  4000.00  NO   5136.666667
# 5     Educación y Cultura  CIUDAD DE MEXICO  3427.00  NO   2086.722222
# 6         Oficina Pública  CIUDAD DE MEXICO  7468.00  NO   9900.000000
# ...                   ...               ...      ...  ..           ...
# 1812      Oficina Pública            OAXACA  1168.78  NO    515.861111
# 1814      Infraestructura  CIUDAD DE MEXICO  3066.46  NO    290.250000
# 1815      Oficina Pública            MÉXICO  1255.00  NO   1855.472222
# 1817  Educación y Cultura            MÉXICO  2355.54  NO     24.222222
# 1818      Infraestructura           HIDALGO  3430.00  NO  61951.861111
#
#       emensualm2           bioclima
# 0       0.843579    Templado Húmedo
# 1       1.971373    Templado Húmedo
# 3       1.284167    Templado Húmedo
# 5       0.608906    Templado Húmedo
# 6       1.325656    Templado Húmedo
# ...          ...                ...
# 1812    0.441367  Cálido Semihúmedo
# 1814    0.094653    Templado Húmedo
# 1815    1.478464           Semifrío
# 1817    0.010283           Semifrío
# 1818   18.061767           Templado
#
# [721 rows x 7 columns]

# %%
#| label: fig-mensual-apf-personam2-sin-aa
#| fig-cap: Consumo total mensual por metro cuadrado de edificios de la APF para los diferentes bioclimas y sin uso de aire acondicionado.

# 1) Orden de bioclimas y paleta
climas = sorted(apf['bioclima'].unique())
colors = sns.color_palette('Set2', n_colors=len(climas))
palette_dict = {clima: colors[i] for i, clima in enumerate(climas)}

# 2) Catplot con orientación horizontal y facetas en columnas
g = sns.catplot(
    data=apf,
    x='emensualm2',        # consumo en el eje X
    y='bioclima',          # bioclima en el eje Y
    hue='bioclima',
    palette=palette_dict,
    kind='box',
    height=4,
    sharex=False,
    col='generico',
    whis=[25, 75],
    showfliers=False,
    col_wrap=3,
    legend=False           # quitamos la leyenda por defecto
)



# 3) Ajustar márgenes para dejar espacio a la derecha
g.fig.subplots_adjust(top=0.85, right=0.75, hspace=0.3)

# … pasos 4 y 5 sin cambios …

# 6) Prepara los parches
handles = [
    mpatches.Patch(color=palette_dict[clima], label=clima)
    for clima in climas
]
g.set_titles(template="{col_name}")
g.set_axis_labels(x_var='kWh/(m2 mes)', y_var='Bioclima')


# # 7) Leyenda vertical al lado derecho
# g.fig.legend(
#     handles=handles,
#     title='Bioclima',
#     loc='center left',
#     bbox_to_anchor=(1.02, 0.5),  # ligeramente fuera del área de dibujo
#     frameon=False
# )

plt.show()

# %%
# función para calcular estadísticas
def calc_stats(df):
    return (
        df
        .groupby('bioclima')['emensualm2']
        .agg(
            P25     = lambda x: x.quantile(0.25),
            Mediana = lambda x: x.quantile(0.50),
            Media   = 'mean',
            P75     = lambda x: x.quantile(0.75)
        )
        .round(2)
        .reset_index()
    )

# para cada uso
for uso, grupo in apf_naa.groupby('generico'):
    stats = calc_stats(grupo)
    tag  = f"tbl-{slugify(uso, lowercase=True)}"
    caption = f"Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **{uso}**"
    
    # print(f"\n**Tabla: {uso}**  \n")
    print(stats.to_markdown(index=False, tablefmt="github"))
    print(f"\n: {caption} {{{{#{tag}}}}}\n")
# Out:
# | bioclima          |   P25 |   Mediana |   Media |   P75 |
# |-------------------|-------|-----------|---------|-------|
# | Cálido Húmedo     |  2.74 |      2.74 |    2.74 |  2.74 |
# | Cálido Seco       |  0.5  |      0.5  |    0.5  |  0.5  |
# | Cálido Semihúmedo |  3.29 |      5.2  |    5.2  |  7.11 |
# | Templado Húmedo   |  1.35 |      2.27 |    2.27 |  3.18 |
# | Templado Seco     |  1.73 |      2.27 |    6.76 |  9.54 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Agrícola, Pecuario y Forestal** {{#tbl-agricola-pecuario-y-forestal}}
#
# | bioclima        |   P25 |   Mediana |   Media |   P75 |
# |-----------------|-------|-----------|---------|-------|
# | Semifrío        |  0.5  |      0.5  |    0.5  |  0.5  |
# | Templado Húmedo |  1.49 |      1.78 |    1.78 |  2.07 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Alojamiento** {{#tbl-alojamiento}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Húmedo         |  0.4  |      0.66 |    0.66 |  0.78 |
# | Cálido Seco           |  0.71 |      0.8  |    0.8  |  0.88 |
# | Cálido Seco Extremoso |  0.47 |      0.54 |    0.75 |  0.93 |
# | Cálido Semihúmedo     |  0.32 |      0.49 |    0.59 |  0.75 |
# | Semifrío              |  0.12 |      0.42 |    0.35 |  0.47 |
# | Semifrío Húmedo       |  0.56 |      0.63 |    0.75 |  0.87 |
# | Semifrío Seco         |  0.36 |      0.53 |    1.04 |  0.71 |
# | Templado              |  0.33 |      0.41 |    0.55 |  0.49 |
# | Templado Húmedo       |  0.32 |      0.49 |    0.85 |  0.82 |
# | Templado Seco         |  0.39 |      0.54 |    0.58 |  0.73 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Comercio** {{#tbl-comercio}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Húmedo         |  0.58 |      1.04 |    0.77 |  1.09 |
# | Cálido Seco Extremoso |  1.31 |      1.71 |    1.71 |  2.12 |
# | Cálido Semihúmedo     |  0.43 |      0.88 |    1.38 |  1.7  |
# | Semifrío              |  1.19 |      1.19 |    1.19 |  1.19 |
# | Templado              |  0.47 |      0.47 |    0.47 |  0.47 |
# | Templado Húmedo       |  0.51 |      1.33 |    1.42 |  1.83 |
# | Templado Seco         |  1.69 |      2.26 |    1.97 |  2.4  |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Comunicaciones y Transporte** {{#tbl-comunicaciones-y-transporte}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Húmedo         |  2.39 |      2.89 |    4.05 |  4.54 |
# | Cálido Seco Extremoso |  1.16 |      2.32 |    2.25 |  3.38 |
# | Cálido Semihúmedo     |  1.33 |      1.52 |    1.62 |  2.07 |
# | Semifrío              |  0.42 |      1.02 |    1    |  1.44 |
# | Semifrío Húmedo       |  0.3  |      0.68 |    0.91 |  1.29 |
# | Templado              |  1.1  |      1.47 |    4.39 |  1.76 |
# | Templado Húmedo       |  1.1  |      1.54 |    1.75 |  2.22 |
# | Templado Seco         |  1.3  |      2.51 |    3.77 |  3.84 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Educación y Cultura** {{#tbl-educacion-y-cultura}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Seco Extremoso |  1.01 |      1.01 |    1.01 |  1.01 |
# | Templado Húmedo       |  0.27 |      0.27 |    0.27 |  0.27 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Habitacional** {{#tbl-habitacional}}
#
# | bioclima          |   P25 |   Mediana |   Media |   P75 |
# |-------------------|-------|-----------|---------|-------|
# | Cálido Semihúmedo |  4.69 |      4.69 |    4.69 |  4.69 |
# | Templado Húmedo   |  5.91 |      7.59 |    7.59 |  9.26 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Industria** {{#tbl-industria}}
#
# | bioclima          |   P25 |   Mediana |   Media |   P75 |
# |-------------------|-------|-----------|---------|-------|
# | Cálido Seco       |  0.17 |      0.17 |    0.17 |  0.17 |
# | Cálido Semihúmedo |  0.4  |      0.57 |    0.57 |  0.74 |
# | Semifrío          |  0.06 |      0.07 |    0.07 |  0.08 |
# | Semifrío Húmedo   |  0.66 |      0.66 |    0.66 |  0.66 |
# | Templado          |  4.65 |      9.12 |    9.12 | 13.59 |
# | Templado Húmedo   |  0.33 |      0.75 |    0.82 |  1.17 |
# | Templado Seco     |  0.19 |      0.19 |    0.19 |  0.19 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Infraestructura** {{#tbl-infraestructura}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Húmedo         |  1.19 |      2.07 |    3.21 |  5.64 |
# | Cálido Seco           |  2    |      2.2  |    2.17 |  2.35 |
# | Cálido Seco Extremoso |  5.37 |      7.45 |    7.45 |  9.53 |
# | Cálido Semihúmedo     |  0.98 |      3.14 |    2.71 |  3.31 |
# | Semifrío              |  1.5  |      1.76 |    2.14 |  2.9  |
# | Semifrío Húmedo       |  1.94 |      3.67 |    3.67 |  5.39 |
# | Semifrío Seco         |  0.72 |      1.32 |    1.22 |  1.82 |
# | Templado              |  0.91 |      1.39 |    2.34 |  2.17 |
# | Templado Húmedo       |  1.38 |      2.35 |    3.45 |  3.82 |
# | Templado Seco         |  0.55 |      0.88 |    1.3  |  1.8  |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Oficina Pública** {{#tbl-oficina-publica}}
#
# | bioclima          |   P25 |   Mediana |   Media |   P75 |
# |-------------------|-------|-----------|---------|-------|
# | Cálido Semihúmedo |  1.56 |      1.56 |    1.56 |  1.56 |
# | Semifrío Húmedo   |  6.82 |      6.82 |    6.82 |  6.82 |
# | Templado          |  0.29 |      0.39 |    0.85 |  1.17 |
# | Templado Húmedo   |  2.33 |      3.23 |    3.3  |  4.3  |
# | Templado Seco     |  0.88 |      0.96 |    0.96 |  1.04 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Recreación** {{#tbl-recreacion}}
#
# | bioclima              |   P25 |   Mediana |   Media |   P75 |
# |-----------------------|-------|-----------|---------|-------|
# | Cálido Húmedo         |  4.5  |      8.27 |    8.38 | 11.43 |
# | Cálido Seco           |  9.81 |     12.82 |   14.68 | 18.62 |
# | Cálido Seco Extremoso |  8.9  |     10.05 |   12.62 | 20.02 |
# | Cálido Semihúmedo     |  3    |      3.52 |    6.03 |  5.38 |
# | Semifrío              |  2.28 |      3.67 |    4.89 |  4.88 |
# | Semifrío Húmedo       |  2.02 |      2.02 |    2.02 |  2.02 |
# | Semifrío Seco         |  4.03 |      5.93 |    7.18 |  9.7  |
# | Templado              |  2.81 |      3.82 |    3.67 |  4.7  |
# | Templado Húmedo       |  2.5  |      3.47 |    4.35 |  5.21 |
# | Templado Seco         |  3.32 |      3.83 |    5.07 |  6.46 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Salud** {{#tbl-salud}}
#
# | bioclima        |   P25 |   Mediana |   Media |   P75 |
# |-----------------|-------|-----------|---------|-------|
# | Templado        |  1.78 |      1.78 |    1.78 |  1.78 |
# | Templado Húmedo |  3.84 |      3.84 |    3.84 |  3.84 |
#
# : Estadísticas de consumo mensual (kWh/m²·mes) por bioclima para uso **Servicios Funerarios** {{#tbl-servicios-funerarios}}
